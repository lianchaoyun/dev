# %%
from hikyuu.interactive import *
from datetime import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-09-08 12:21:50,344 [INFO] NumExpr defaulting to 4 threads. [numexpr.utils::_init_num_threads]
# 2024-09-08 12:21:51,942 [INFO] hikyuu version: 2.1.4_202409041750_RELEASE_windows_x64 [<module>] (c:\app\env\python3\lib\site-packages\hikyuu\__init__.py:97) [hikyuu::hku_info]
# 2024-09-08 12:21:55.376 [HKU-I] - Using SQLITE3 BaseInfoDriver (BaseInfoDriver.cpp:57)
# 2024-09-08 12:21:55.410 [HKU-I] - Loading market information... (StockManager.cpp:454)
# 2024-09-08 12:21:55.412 [HKU-I] - Loading stock type information... (StockManager.cpp:472)
# 2024-09-08 12:21:55.416 [HKU-I] - Loading stock information... (StockManager.cpp:374)
# 2024-09-08 12:21:55.566 [HKU-I] - Loading stock weight... (StockManager.cpp:490)
# 2024-09-08 12:21:56.033 [HKU-I] - Loading block... (StockManager.cpp:113)
# 2024-09-08 12:21:56.038 [HKU-I] - Loading KData... (StockManager.cpp:117)
# 2024-09-08 12:21:56.039 [HKU-I] - Preloading all day kdata to buffer ! (StockManager.cpp:153)
# 2024-09-08 12:21:56.043 [HKU-I] - 0.64s Loaded Data. (StockManager.cpp:125)

# %%
s = sm['sz000001']
k = s.get_kdata(Query(start=-250, end=None , ktype=Query.DAY, recover_type=Query.FORWARD))  
k.plot()
print(k)
print(k[-5:])

s = sm['sz000001']
k = s.get_kdata(Query(-200))


#抽取K线收盘价指标，一般指标计算参数只能是指标类型，所以必须先将K线数据生成指标类型
c = CLOSE(k)

#计算收盘价的EMA指标
a = EMA(c)

#绘制指标
c.plot(legend_on=True)
a.plot(new=False, legend_on=True)

#绘制柱状图
a.bar()

#修正下柱状图，使其更美观
PRICELIST([x-9 for x in a]).bar()
# Out:
# KData{
#   size : 250
#   stock: Stock(SZ, 000001, 平安银行, A股, 1, 1991-04-03 00:00:00, +infinity),
#   query: KQuery(-250, 9223372036854775807, INDEX, DAY, FORWARD)
# }
# [KRecord(Datetime(202409020000), 10.1200, 10.2100, 10.0900, 10.1100, 98389.9000, 968835.0000), KRecord(Datetime(202409030000), 10.1100, 10.1300, 10.0000, 10.0800, 92088.5000, 916581.0000), KRecord(Datetime(202409040000), 10.0500, 10.1500, 10.0000, 10.0200, 85222.5000, 847992.0000), KRecord(Datetime(202409050000), 10.0300, 10.0800, 9.9800, 10.0700, 59584.6000, 594208.0000), KRecord(Datetime(202409060000), 10.0600, 10.2100, 10.0500, 10.0800, 89150.8000, 878865.0000)]

# %%
#创建模拟交易账户进行回测，初始资金30万
my_tm = crtTM(init_cash = 300000)

#创建信号指示器（以5日EMA为快线，5日EMA自身的10日EMA作为慢线，快线向上穿越慢线时买入，反之卖出）
my_sg = SG_Flex(EMA(C, n=5), slow_n=10)

#固定每次买入1000股
my_mm = MM_FixedCount(1000)

#创建交易系统并运行
sys = SYS_Simple(tm = my_tm, sg = my_sg, mm = my_mm)
sys.run(sm['sz000001'], Query(-150))

# %%
#绘制系统信号
sys.plot()

k = sm['sz000001'].get_kdata(Query(-150))
c = CLOSE(k)
fast = EMA(c, 5)
slow = EMA(fast, 10)

#绘制信号指示器使用两个指标
fast.plot(new=False)
slow.plot(new=False)

# %%
#绘制资金收益曲线
x = my_tm.get_profit_curve(k.get_datetime_list(), Query.DAY)
x = PRICELIST(x)
x.plot()

# %%
#回测统计
per = Performance()
print(per.report(my_tm, Datetime(datetime.today())))
# Out:
# 帐户初始金额: 300000.00
# 累计投入本金: 300000.00
# 累计投入资产: 0.00
# 累计借入现金: 0.00
# 累计借入资产: 0.00
# 累计红利: 0.00
# 现金余额: 300360.00
# 未平仓头寸净值: 0.00
# 当前总资产: 300360.00
# 已平仓交易总成本: 0.00
# 已平仓净利润总额: 360.00
# 单笔交易最大占用现金比例%: 3.52
# 交易平均占用现金比例%: 3.43
# 已平仓帐户收益率%: 0.12
# 帐户年复合收益率%: 0.20
# 帐户平均年收益率%: 0.20
# 赢利交易赢利总额: 1470.00
# 亏损交易亏损总额: -1110.00
# 已平仓交易总数: 8.00
# 赢利交易数: 2.00
# 亏损交易数: 6.00
# 赢利交易比例%: 25.00
# 赢利期望值: 45.00
# 赢利交易平均赢利: 735.00
# 亏损交易平均亏损: -185.00
# 平均赢利/平均亏损比例: 3.97
# 净赢利/亏损比例: 1.32
# 最大单笔赢利: 930.00
# 最大单笔盈利百分比%: 9.67
# 最大单笔亏损: -460.00
# 最大单笔亏损百分比%: -4.42
# 赢利交易平均持仓时间: 41.50
# 赢利交易最大持仓时间: 46.00
# 亏损交易平均持仓时间: 8.67
# 亏损交易最大持仓时间: 14.00
# 空仓总时间: 80.00
# 空仓时间/总时间%: 37.00
# 平均空仓时间: 10.00
# 最长空仓时间: 29.00
# 最大连续赢利笔数: 1.00
# 最大连续亏损笔数: 4.00
# 最大连续赢利金额: 930.00
# 最大连续亏损金额: -770.00
# R乘数期望值: 0.01
# 交易机会频率/年: 13.64
# 年度期望R乘数: 0.14
# 赢利交易平均R乘数: 0.08
# 亏损交易平均R乘数: -0.02
# 最大单笔赢利R乘数: 0.10
# 最大单笔亏损R乘数: -0.04
# 最大连续赢利R乘数: 0.10
# 最大连续亏损R乘数: -0.02
